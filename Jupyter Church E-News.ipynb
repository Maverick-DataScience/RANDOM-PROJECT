# %% [markdown]
# # DATA PROCESSING for Central Baptist Church Survey
# The purpose of this project is to find how effective is our church E-News Service is, for giving an information regarding church event, service, or community and what content can be improved or changed.
#
# In this project, I will try to process and analyze the data that has been collected from the survey conducted in Central Baptist Church at 11th December and 18th December 2022. I will try to group the interest by age group and see which news source the particular age group accessed the most and the number of news each age group read. I will also try to find which news messages people think aren't delivered well. For this question in particular there's no need to group it by age group.
#
# While the number of sample is not big enough to represent the whole International Service community, we assume that the sample itself already can present the community.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('Untitled form.csv', skipinitialspace=True, usecols=range(1,7)) # importing the csv data

# %%
data
# Out:
#    What age group are you in?  \
# 0                         50+
# 1                       35-49
# 2                       18-24
# 3                       35-49
# 4                       18-24
# 5                       18-24
# 6                    Under 18
# 7                         50+
# 8                       25-34
# 9                         50+
# 10                      35-49
# 11                      35-49
# 12                      35-49
# 13                      35-49
# 14                        50+
# 15                   Under 18
# 16                      25-34
# 17                      25-34
# 18                      18-24
# 19                      25-34
# 20                   Under 18
# 21                   Under 18
# 22                      18-24
# 23                      25-34
# 24                        50+
# 25                      18-24
# 26                      25-34
# 27                      25-34
# 28                        50+
# 29                        50+
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data_split = pd.read_csv('Untitled form split.csv', skipinitialspace=True, usecols=range(1,7), encoding='cp1252') 
# data_split is file where the answer for 'Where do you usually receive church news is separated for multiple answer'

# %%
data_split
# Out:
#    What age group are you in?  \
# 0                         50+
# 1                       35-49
# 2                       18-24
# 3                       18-24
# 4                       35-49
# 5                       35-49
# 6                       18-24
# 7                       18-24
# 8                       18-24
# 9                       18-24
# 10                   Under 18
# 11                   Under 18
# 12                        50+
# 13                        50+
# 14                      25-34
# 15                      25-34
# 16                        50+
# 17                      35-49
# 18                      35-49
# 19                      35-49
# 20                      35-49
# 21                      35-49
# 22                      35-49
# 23                        50+
# 24                   Under 18
# 25                      25-34
# 26                      25-34
# 27                      25-34
# 28                      18-24
# 29                      25-34
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data_split_2 = pd.read_csv('Untitled form split 2.csv', skipinitialspace=True, usecols=range(1,7), encoding='cp1252')

# %%
data_split_2
# Out:
#    What age group are you in?  \
# 0                         50+
# 1                       35-49
# 2                       35-49
# 3                       18-24
# 4                       35-49
# 5                       18-24
# 6                       18-24
# 7                       18-24
# 8                    Under 18
# 9                    Under 18
# 10                        50+
# 11                      25-34
# 12                      25-34
# 13                      25-34
# 14                        50+
# 15                        50+
# 16                      35-49
# 17                      35-49
# 18                      35-49
# 19                      35-49
# 20                      35-49
# 21                        50+
# 22                   Under 18
# 23                      25-34
# 24                      25-34
# 25                      18-24
# 26                      25-34
# 27                   Under 18
# 28                   Under 18
# 29                      18-24
# ...

# %% [markdown]
# ##### Note: Data_split is data where the multiple answer for 'Where do you usually receive Church News from?' is separated and Data_Split_2 is a data where the multiple answer for "What news messages from below do you think aren't delivered well?" is separated

# %%
data.shape
print("The number of sample collected in total is", data.shape[0])
# Out:
# The number of sample collected in total is 34

# %% [markdown]
# ##### As we can see, there is a total of 34 response sample from our data

# %%
data.isnull().sum()
# Out:
# What age group are you in?                                                0
# Where do you usually receive Church News from? (maximum 2)                0
# In the past 2 months, how many Weekly E-News Bulletins have you read?     0
# What news messages from below do you think aren't delivered well?        13
# How can we deliver our news more effectively?                            18
# How can we improve our church news?                                      21
# dtype: int64

# %% [markdown]
# ##### There is no empty response in AGE GROUP, WHERE RECEIVE NEWS, HOW MANY E-NEWS READ.
#
# ##### However, some people did not answer the question 'What news messages from below do you think aren't delivered well?'  (there is 13 people choose to not answer).This can be interpreted as there's nothing wrong with the current E-News or they simply just didn't answer.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   What age group are you in?                                             34 non-null     object
#  1   Where do you usually receive Church News from? (maximum 2)             34 non-null     object
#  2   In the past 2 months, how many Weekly E-News Bulletins have you read?  34 non-null     object
#  3   What news messages from below do you think aren't delivered well?      21 non-null     object
#  4   How can we deliver our news more effectively?                          16 non-null     object
#  5   How can we improve our church news?                                    13 non-null     object
# dtypes: object(6)
# memory usage: 1.7+ KB

# %%
data.columns.tolist()
# Out:
# ['What age group are you in?',
#  'Where do you usually receive Church News from? (maximum 2)',
#  'In the past 2 months, how many Weekly E-News Bulletins have you read?',
#  "What news messages from below do you think aren't delivered well?",
#  'How can we deliver our news more effectively?',
#  'How can we improve our church news?']

# %%
plt.figure(figsize=(15,5))
sns.set(style="darkgrid",font_scale=1.2)
g1 = sns.countplot(data['What age group are you in?'])
g1.bar_label(g1.containers[0])
plt.xlabel("Age", size=20, fontweight='bold')
plt.ylabel("Numbers of Participant", size=20, fontweight='bold')
# Out:
# C:\Users\Maverick\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Numbers of Participant')

# %% [markdown]
# ##### From the graph above, most of the participant comes from people at the age above 50, followed by people from age range 25-34. People below age 18 has the least amount of participant in this survey

# %%
plt.figure(figsize=(15,5))
sns.set(style="darkgrid", font_scale=1.2)
g2 = sns.countplot(data_split['Where do you usually receive Church News from? (maximum 2)'])
g2.bar_label(g.containers[0])
plt.xticks(rotation="45")
plt.xlabel("Access Platform", size=20, fontweight='bold')
plt.ylabel("Numbers of Vote", size=20, fontweight='bold')
# Out:
# C:\Users\Maverick\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Numbers of Vote')

# %% [markdown]
# ##### From the graph above, most CBC church member find access of E-News through email followed by in-service announcement. There's only several person who gets update about church event by word of mouth or website

# %%
import numpy as np
plt.figure(figsize=(15,5))
sns.set(style="darkgrid",font_scale=1.2)
g3 = sns.countplot(data['In the past 2 months, how many Weekly E-News Bulletins have you read?'])
g3.bar_label(g3.containers[0])
plt.xticks(rotation="45")
plt.yticks(np.arange(0,20,5))
plt.xlabel("Times Reading E-News", size=20,fontweight='bold')
plt.ylabel("Numbers of Vote", size=20, fontweight='bold')
# Out:
# C:\Users\Maverick\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Numbers of Vote')

# %% [markdown]
# #####  Most of the participant had read around 4-8 times E-News every 2 month

# %%
sorted_data
# Out:
#   What news messages from below do you think aren't delivered well?  Count
# 0                             Church Meeting Details                     4
# 1  Church Ministry Details (Life Groups, Worship,...                    14
# 2                                        Pastor Desk                     5
# 3  Weekly Announcement Details (such as Contact P...                     8
# 4      Weekly Announcements (Events, Messages, etc.)                     5

# %%
import textwrap
plt.figure(figsize=(14,5))
plt.xlim(0, 15)
plt.xlabel("Numbers of Vote", size=15, fontweight='bold')

text=['Pastor Desk','Weekly Announcement Details (such as Contact Person, Contact Number, Date & Time, Venue, etc.)','Church Ministry Details (Life Groups, Worship, Welcoming, etc.)','Church Meeting Details', 'Weekly Announcements (Events, Messages, etc.)']
sorted_data = data_split_2.groupby(["What news messages from below do you think aren't delivered well?"])["What news messages from below do you think aren't delivered well?"].agg('count').reset_index(name='Count')

ax = plt.barh(y, sorted_data['Count'])
plt.yticks(y, [textwrap.fill(t, 30) for t in text], fontsize = 15, horizontalalignment='right', fontweight='bold')
plt.bar_label(ax)
plt.title("Information That Is Not Clear Enough", size = 30, fontweight = 100, pad=30, loc='center')
# Out:
# Text(0.5, 1.0, 'Information That Is Not Clear Enough')

# %%
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

fig, ax = plt.subplots()

hbars = ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

# Label with specially formatted floats
ax.bar_label(hbars, fmt='%.2f')
ax.set_xlim(right=15)  # adjust xlim to fit labels
# Out:
# (0.0, 15.0)

# %% [markdown]
# ##### Based from the graph above, lot of people think Church Ministry Details still haven't been delivered well. Several people think that other information from the survey are also isn't conveyed properly.

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder(dtype = int)
enc
# Out:
# OrdinalEncoder(dtype=<class 'int'>)

# %%
data['Age_Group'] = enc.fit_transform(data[['What age group are you in?']])
data['News_Source'] = enc.fit_transform(data[['Where do you usually receive Church News from? (maximum 2)']])
data['No_News_Read'] = enc.fit_transform(data[['In the past 2 months, how many Weekly E-News Bulletins have you read?']])
data.columns.tolist()
# Out:
# ['What age group are you in?',
#  'Where do you usually receive Church News from? (maximum 2)',
#  'In the past 2 months, how many Weekly E-News Bulletins have you read?',
#  "What news messages from below do you think aren't delivered well?",
#  'How can we deliver our news more effectively?',
#  'How can we improve our church news?',
#  'Age_Group',
#  'News_Source',
#  'No_News_Read']

# %%
data_split['Age_Group'] = enc.fit_transform(data_split[['What age group are you in?']])
data_split['News_Source'] = enc.fit_transform(data_split[['Where do you usually receive Church News from? (maximum 2)']])
data_split['No_News_Read'] = enc.fit_transform(data_split[['In the past 2 months, how many Weekly E-News Bulletins have you read?']])
data_split.columns.tolist()
# Out:
# ['What age group are you in?',
#  'Where do you usually receive Church News from? (maximum 2)',
#  'In the past 2 months, how many Weekly E-News Bulletins have you read?',
#  "What news messages from below do you think aren't delivered well?",
#  'How can we deliver our news more effectively?',
#  'How can we improve our church news?',
#  'Age_Group',
#  'News_Source',
#  'No_News_Read']

# %% [markdown]
# # Erasing the 'What age group are you in?', 'Where do you usually receive Church News from? (maximum 2)', 'In the past 2 months, how many Weekly E-News Bulletins have you read?' question with shorter one

# %%
new_data = data.drop(columns=['What age group are you in?','Where do you usually receive Church News from? (maximum 2)', 'In the past 2 months, how many Weekly E-News Bulletins have you read?'])
new_data
# Out:
#    What news messages from below do you think aren't delivered well?  \
# 0                                                 NaN
# 1   Pastor Desk;Weekly Announcement Details (such ...
# 2   Church Ministry Details (Life Groups, Worship,...
# 3                                                 NaN
# 4   Weekly Announcement Details (such as Contact P...
# 5   Church Ministry Details (Life Groups, Worship,...
# 6   Pastor Desk;Church Ministry Details (Life Grou...
# 7                                                 NaN
# 8   Pastor Desk;Weekly Announcement Details (such ...
# 9   Church Meeting Details;Church Ministry Details...
# 10  Weekly Announcements (Events, Messages, etc.);...
# 11                                                NaN
# 12                                                NaN
# 13                             Church Meeting Details
# 14                                                NaN
# 15                                                NaN
# ...

# %%
new_data_split = data_split.drop(columns=['What age group are you in?','Where do you usually receive Church News from? (maximum 2)', 'In the past 2 months, how many Weekly E-News Bulletins have you read?'])
new_data_split
# Out:
#    What news messages from below do you think aren't delivered well?  \
# 0                                                 NaN
# 1   Pastor Desk;Weekly Announcement Details (such ...
# 2   Church Ministry Details (Life Groups, Worship,...
# 3   Church Ministry Details (Life Groups, Worship,...
# 4                                                 NaN
# 5                                                 NaN
# 6   Weekly Announcement Details (such as Contact P...
# 7   Weekly Announcement Details (such as Contact P...
# 8   Church Ministry Details (Life Groups, Worship,...
# 9   Church Ministry Details (Life Groups, Worship,...
# 10  Pastor Desk;Church Ministry Details (Life Grou...
# 11  Pastor Desk;Church Ministry Details (Life Grou...
# 12                                                NaN
# 13                                                NaN
# 14  Pastor Desk;Weekly Announcement Details (such ...
# 15  Pastor Desk;Weekly Announcement Details (such ...
# ...

# %% [markdown]
# # CLASSIFYING THE AGE RANGE

# %% [markdown]
# Note: Age Group 0 is 18-24
# 1 is 25-34
# 2 IS 35-49
# 3 is 50+
# 4 is Under 18

# %% [markdown]
# ### Youth (18-24)

# %%
Youth = new_data[new_data["Age_Group"]==0]
Youth
# Out:
#    What news messages from below do you think aren't delivered well?  \
# 2   Church Ministry Details (Life Groups, Worship,...
# 4   Weekly Announcement Details (such as Contact P...
# 5   Church Ministry Details (Life Groups, Worship,...
# 18  Church Ministry Details (Life Groups, Worship,...
# 22                                                NaN
# 25  Church Meeting Details;Church Ministry Details...
#
#    How can we deliver our news more effectively?  \
# 2                                            NaN
# 4                                            NaN
# 5                        Instagram! / tiktok lol
# 18                                           NaN
# 22                                           NaN
# 25                                           NaN
#
#    How can we improve our church news?  Age_Group  News_Source  No_News_Read
# 2                                  NaN          0            3             1
# ...

# %%
Youth_Split = new_data_split[new_data_split["Age_Group"]==0]
Youth_Split
# Out:
#    What news messages from below do you think aren't delivered well?  \
# 2   Church Ministry Details (Life Groups, Worship,...
# 3   Church Ministry Details (Life Groups, Worship,...
# 6   Weekly Announcement Details (such as Contact P...
# 7   Weekly Announcement Details (such as Contact P...
# 8   Church Ministry Details (Life Groups, Worship,...
# 9   Church Ministry Details (Life Groups, Worship,...
# 28  Church Ministry Details (Life Groups, Worship,...
# 32                                                NaN
# 33                                                NaN
# 36  Church Meeting Details;Church Ministry Details...
# 37  Church Meeting Details;Church Ministry Details...
#
#    How can we deliver our news more effectively?  \
# 2                                            NaN
# 3                                            NaN
# 6                                            NaN
# 7                                            NaN
# ...

# %% [markdown]
# ### Young Adult (25-34)

# %%
Y_Adult = new_data[new_data["Age_Group"]==1]
Y_Adult_Split = new_data_split[new_data_split["Age_Group"]==1]

# %% [markdown]
# ### Adult (35-49)

# %%
Adult = new_data[new_data["Age_Group"]==2]
Adult_Split = new_data_split[new_data_split["Age_Group"]==2]

# %% [markdown]
# ### Elder (50+)

# %%
Elder = new_data[new_data["Age_Group"]==3]
Elder_Split = new_data_split[new_data_split["Age_Group"]==3]

# %% [markdown]
# ### Under 18

# %%
U_18 = new_data[new_data["Age_Group"]==4]
U_18_Split = new_data_split[new_data_split["Age_Group"]==4]

# %% [markdown]
# Now, let's find for which news platform each age group accessed their information from

# %% [markdown]
# # NEWS SOURCE BY AGE GROUP

# %% [markdown]
# News Source
# 0 Church Website
# 1 E-News Bulletin (Email)
# 2 In service Annoucement
# 3 Word of Mouth

# %%
plt.title?

# %%
# Note for workflow inspection: the x value in the plt.bar is decided by
# outputting the Youth_News_Source and see which News Source they are from.. please refer to the information above
Youth_News_Source = Youth_Split.groupby(['News_Source'])['News_Source'].agg('count').reset_index(name='Count')

plt.ylim(0, 10)
plt.xlabel("News_Source", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("Number of people using News Source for People with Age Range 18-24", size = 20, fontweight='bold', pad=30)
plt.bar(data=Youth_News_Source, height = 'Count', x = ['E-News Bulletin (Email)','In-service Announcement', 'Word of Mouth'])
# Out:
# <BarContainer object of 3 artists>

# %%
Y_Adult_News_Source = Y_Adult_Split.groupby(['News_Source'])['News_Source'].agg('count').reset_index(name='Count')

plt.ylim(0, 10)
plt.xlabel("News_Source", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("Number of people using News Source for People with Age Range 25-34", size = 15, fontweight='bold', pad=30)
plt.bar(data=Y_Adult_News_Source, height = 'Count', x = ['Church Website','E-News Bulletin (Email)','In-service Announcement', 'Word of Mouth'])
# Out:
# <BarContainer object of 4 artists>

# %%
Adult_News_Source = Y_Adult_Split.groupby(['News_Source'])['News_Source'].agg('count').reset_index(name='Count')

plt.ylim(0, 10)
plt.xlabel("News_Source", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("Number of people using News Source for People with Age Range 35-49", size = 15, fontweight='bold', pad=30)
plt.bar(data=Adult_News_Source, height = 'Count', x = ['Church Website','E-News Bulletin (Email)','In-service Announcement', 'Word of Mouth'])
# Out:
# <BarContainer object of 4 artists>

# %%
Elder_News_Source = Elder_Split.groupby(['News_Source'])['News_Source'].agg('count').reset_index(name='Count')

plt.ylim(0, 10)
plt.xlabel("News_Source", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("Number of people using News Source for People with Age Range 50+", size = 15, fontweight='bold', pad=30)
plt.bar(data=Elder_News_Source, height = 'Count', x = ['Church Website','E-News Bulletin (Email)','In-service Announcement'])
# Out:
# <BarContainer object of 3 artists>

# %%
U_18_News_Source = U_18_Split.groupby(['News_Source'])['News_Source'].agg('count').reset_index(name='Count')

plt.figure(figsize=[4,5])
plt.ylim(0, 10)
plt.xlabel("News_Source", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("Number of people using News Source for People with Age Range Under 18", size = 15, fontweight='bold', pad=30)
plt.bar(data=U_18_News_Source, height = 'Count', x = ['Church Website','In-service Announcement'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # In the past 2 months, how many Weekly E-News Bulletins have you read? (by Age Group)

# %% [markdown]
# No of News Read
# 0 1-3 times
# 1 4-8 times
# 2 I have not read

# %% [markdown]
# ### Youth (Age 18-24)

# %%
# Note for workflow inspection: the x value in the plt.bar is decided by
# outputting the Youth_News_Source and see which News Source they are from.. please refer to the information above
Youth_Read = Youth.groupby(['No_News_Read'])['No_News_Read'].agg('count').reset_index(name='Count')

plt.ylim(0, 10)
plt.xlabel("Times people read E-News", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("How many times People with Age Range 18-24 Access E-News Content Past 2 months", size = 15,  fontweight='bold', pad=30)
plt.bar(data=Youth_Read, height = 'Count', x = ['1-3 times','4-8 times','I have not read'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ##### People with age range 18-24 have a more spreadout amount of times reading E-News

# %%
# Note for workflow inspection: the x value in the plt.bar is decided by
# outputting the Youth_News_Source and see which News Source they are from.. please refer to the information above
Y_Adult_Read = Y_Adult.groupby(['No_News_Read'])['No_News_Read'].agg('count').reset_index(name='Count')

plt.figure(figsize=[4,5])
plt.ylim(0, 10)
plt.xlabel("Times people read E-News", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("How many times People with Age Range 25-34 Access E-News Content Past 2 months", size = 15,fontweight='bold', pad=30)
plt.bar(data=Y_Adult_Read, height = 'Count', x = ['1-3 times','4-8 times'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ##### People with age range 25-34 read E-News every 2 months

# %%
# Note for workflow inspection: the x value in the plt.bar is decided by
# outputting the Youth_News_Source and see which News Source they are from.. please refer to the information above
Adult_Read = Adult.groupby(['No_News_Read'])['No_News_Read'].agg('count').reset_index(name='Count')

plt.ylim(0, 10)
plt.xlabel("Times people read E-News", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("How many times People with Age Range 35-49 Access E-News Content Past 2 months", size = 15, fontweight='bold', pad=30)
plt.bar(data=Adult_Read, height = 'Count', x = ['1-3 times','4-8 times','I have not read'])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ##### People with age range 35-49 read E-News and some of them didn't

# %%
# Note for workflow inspection: the x value in the plt.bar is decided by
# outputting the Youth_News_Source and see which News Source they are from.. please refer to the information above
Elder_Read = Elder.groupby(['No_News_Read'])['No_News_Read'].agg('count').reset_index(name='Count')

plt.figure(figsize=[4,5])
plt.ylim(0, 10)
plt.xlabel("Times people read E-News", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("How many times People with Age Range 50+ Access E-News Content Past 2 months", size = 15, fontweight='bold', pad=30)
plt.bar(data=Elder_Read, height = 'Count', x = ['4-8 times'], width = 1)
# Out:
# <BarContainer object of 1 artists>

# %% [markdown]
# #### People age above 50+ read E-News at least 4 times every 2 months

# %%
# Note for workflow inspection: the x value in the plt.bar is decided by
# outputting the Youth_News_Source and see which News Source they are from.. please refer to the information above
U_18_Read = U_18.groupby(['No_News_Read'])['No_News_Read'].agg('count').reset_index(name='Count')

plt.figure(figsize=[4,5])
plt.ylim(0, 10)
plt.xlabel("Times people read E-News", size = 13, fontweight='bold')
plt.ylabel("Number of Vote", size = 13, fontweight='bold')
plt.xticks(rotation="45", size=11)
plt.title("How many times People with Age Range Under 18 Access E-News Content Past 2 months", size = 15, fontweight='bold', pad=30)
plt.bar(data=Elder_Read, height = 'Count', x = ['I have not read'], width = 1)
# Out:
# <BarContainer object of 1 artists>

# %% [markdown]
# ##### People under the age of 18 doesn't read the E-News at all. And since from the survey these age group are getting the church news from In-service Announcements and from church website... this could mean they either only learn about the church news only from In-service Announcements or they occasionally access church E-News. But the participant in this survey for this age grou[ definitely haven't access the church news from the church website past 2 months]
